# %% [markdown]
# <div class="alert alert-info" markdown="1">
#
# #### Lab 1
#
# # Mathematical Foundations
#
# ### Math 124: Vectors, Matrices, and Applications, Fall 2026
#
# <small><a style="text-decoration: none" href="">math124.org</a></small>
#
# </div>
#
#
# ### Instructions
#
# Most homeworks and some labs will have a Jupyter Notebook, like this one, containing Python code that supplements our understanding of the relevant mathematical ideas of the week.
#
# ---
#
# To open this notebook, click the Google Colab link under "Code" on the course website for Lab 1. Instructions on how to use Google Colab are at [math124.org/running-code](https://math124.org/running-code).
#
# **Most importantly, make sure to click "Copy to Drive" and rename the notebook before proceeding!**
#
# ---
#
# This first lab has **no math** and very little code: its job is to familiarize you with Jupyter Notebooks. Homework 1 will introduce slightly more Python syntax, but we will keep the introduction gentle: remember, code will not appear on quizzes and exams.
#
# To receive credit for the programming component of the lab, work through this entire notebook and show your lab TA the graph you create at the very bottom, with your name in it.

# %% [markdown]
# ## What is a notebook?
#
# ---
#
# A Jupyter notebook lets you write text, run code, and look at pictures all in the same document. Scientists across every field use them, and they are a great way to learn linear algebra, because they allow us to work with real data and visualize concepts interactively.
#
# A notebook is made of **cells**, and there are two kinds:
#
# - **Markdown cells** hold text and images — like the one you are reading right now.
# - **Code cells** hold code you can run. They have a grey background.
#
# To **run** a cell, click on it and press <kbd>shift</kbd> + <kbd>enter</kbd>.
#
# Try it right now on *this very cell*: double-click it to see the raw text underneath, then press <kbd>shift</kbd> + <kbd>enter</kbd> to turn it back into nicely formatted text.
#
# <small>Fun fact: "Jupyter" stands for **Ju**lia, **Py**thon, and **R** — the three languages it was first built for. And Python isn't named after the snake; its creator named it after *Monty Python's Flying Circus*.</small>

# %% [markdown]
# ## Python as a calculator
#
# ---
#
# The language we will write code in is **Python** (though Jupyter Notebooks support other languages, too). At its most basic, a code cell is just a calculator: you type an expression, run the cell, and it shows you the answer.
#
# Run the cell below with <kbd>shift</kbd> + <kbd>enter</kbd>.

# %%
2 + 2

# %%
# Python ignores this line, but you can read it!
17 ** 2

# %%
25 / 4

# %%
# Integer division.
25 // 4

# %%
# Why do we only see one line of output?
2 - 4
18 + 15.0

# %% [markdown]
# **Your turn:** In the cell below, evaluate the expression
#
# $$2^{10} + \frac{3039}{3} - \sqrt{121}$$

# %%
# Your expression goes here (delete this comment!)

# %% [markdown]
# ## Storing values with variables
#
# ---
#
# Usually we don't want an answer to vanish the moment it appears. We want to **store** it under a name and reuse it later. We do that with the `=` sign. Any line of code with `=` is called an assignment statement.

# %%
count = 7 + 9
count

# %% [markdown]
# Read `count = 7+9` as an instruction to Python: evaluate the expression on the right side of the `=`, and store that result under the name `count`.
#
# The value of a variable is not set in stone. Running another assignment with the same name changes which value that name refers to.

# %%
count = 12

# %% [markdown]
# I can even change `count` in a way that uses `count`!

# %%
count = count + 1
count

# %% [markdown]
# Once a value is stored, every later cell can use it. Run the cell below and watch it reuse `count` from above.

# %%
count / 15

# %% [markdown]
# <div class="alert alert-warning" markdown="1">
#
# **Note:** Cells remember things in the order you *run* them, not the order they appear on the page. If a cell complains that a name is "not defined," you probably skipped the cell above it. Run the cells top to bottom.
#
# </div>

# %% [markdown]
# ## Notebook memory and restarting the kernel
#
# ---
#
# The **kernel** is the engine that runs Python. You can think of it as the notebook's short-term memory: whenever you run a cell with an assignment statement, such as `count = 12`, the kernel remembers that name and value for later cells. It remembers the order in which you **run** cells, even if that order differs from the order on the page.

# %%
# We defined this a few cells ago, but the kernel still remembers it.
count

# %% [markdown]
# If your Colab session ends or you restart the kernel, the notebook forgets those stored values. The code cells remain on the page, but you need to run them again. When you return to a notebook, run its cells from top to bottom so that every name is defined before it is used. For a reproducible notebook:
#
# 1. Don't delete a cell that defines a variable used later.
# 2. Don't use a variable above the cell where it is defined.
# 3. Don't overwrite built-in names such as `min`, `max`, or `round`, which already have some meaning (as we will see shortly).
#
# If something seems wrong, first save your notebook. Then use Colab's **Runtime** menu to **Restart session**. This gives the kernel a fresh start. After restarting, run all cells from the top. When restarting your session, we also recommend clicking the triangle next to **Run all** and selecting "Clear outputs", so that it is clear that none of your cells have been run yet.

# %% [markdown]
# ## Strings
#
# ---
#
# So far, the only values we've assigned to our variables have been numbers. Technically, we've seen two types of numbers in Python: `int`s and `float`s.

# %%
2 * 3

# %%
# The decimal makes this a float, different from the int 6 above.
24 / 4

# %% [markdown]
# Text in Python is stored as a string, or `str` for short. To create a string, use single quotes, double quotes, or triple quotes. The following cells illustrate some key string behavior.

# %%
"Go Blue!"

# %%
"1998" # A string, not a number!

# %%
"1998" + 3 # Gives us an error. When you see an error message, read the last line first.

# %%
"1998" * 3 # Works!

# %%
"""
Triple quotes are used for strings that span multiple lines.
Like this one!
"""

# %%
print("""
Triple quotes are used for strings that span multiple lines.
Like this one!
""")

# %% [markdown]
# The error in the cell `"1998" + 3` was intentional here. Any time you encounter an error, read the last line of the error message first. If we ever ask you to submit your notebook anywhere, make sure that none of your cells cause an error, when the cells in your notebook are run in order from top to bottom.

# %% [markdown]
# ## Functions
#
# ---
#
# In high school you used functions like $f(x) = x^2$, or $\sin(x)$, or $\max(a, b)$: you plug in one or more **inputs** and get an **output** back.
#
# Python functions follow the same principle. To use, or **call**, a function, you write the function's name, then its inputs — called **arguments** — in parentheses:
#
# $$\underbrace{\texttt{round}}_{\text{name}}(\underbrace{\texttt{3.14159},\ \texttt{2}}_{\text{arguments}})\;\longrightarrow\; \texttt{3.14}$$
#
# Python comes with several functions already built in. Run the next few cells to see a few in action.

# %%
round(3.14159)

# %%
round(3.14159, 2)

# %%
abs(-4)

# %%
max(4, 9, 7)

# %%
type(2 * 3)

# %%
type(24 / 4)

# %% [markdown]
# We should avoid using `round`, `abs`, `max`, `type`, and the names of other built-in functions for our variables, as this will overwrite the behavior of these functions. (If you do this, change the code in which you re-assigned one of these names, and restart your kernel.)

# %% [markdown]
# There are many more functions built into Python than you will probably ever memorize – it is fine to consult the internet to remember the names of them! Notebooks have some support built-in. Put a `?` after any function's name to pull up its instructions, and press <kbd>Tab</kbd> after typing a few letters to autocomplete. Run this:

# %%
round?

# %% [markdown]
# ## Import statements
#
# ---
#
# Not everything is built into Python. A **package** is a bundle of ready-made functions somebody else already wrote — think of it as a toolbox you borrow instead of forging every tool yourself. In Homework 1, we will introduce you to `numpy`, a very common package in Python for performing linear algebra.
#
# To use a toolbox, you **import** it. We've written a small one for this lab, stored in the `utils` folder in our GitHub repository. Run the cell below to download its files, and then import, a function named `plot_names`.

# %%
from pathlib import Path
from urllib.request import urlretrieve

base_url = "https://raw.githubusercontent.com/math-124/fa26-code/main/labs/lab01"
files = ["utils/__init__.py", "utils/plot_names.py", "utils/baby.csv", "utils/first_names.npy"]

for filename in files:
    path = Path(filename)
    path.parent.mkdir(parents=True, exist_ok=True)
    if not path.exists():
        urlretrieve(f"{base_url}/{filename}", path)

from utils.plot_names import plot_names

# %% [markdown]
# Nothing visible happened, and that's to be expected. But now, the name `plot_names` means something in our notebook:

# %%
plot_names

# %% [markdown]
# Let's use it!

# %% [markdown]
# ## US Social Security Administration data
#
# ---
#
# The U.S. Social Security Administration publishes the number of babies born with each name, each year, going back to 1880 (subject to some censoring for privacy reasons, e.g. if a name was extremely rare). The graph below uses the real SSA data through 2022.
#
# Run the cell below to see an interactive line chart. The dropdown menu that appears has the first name of all students and instructors in this class, including yours! Use the dropdown to pick your first name and see the number of babies born per year with your name.

# %%
plot_names()

# %% [markdown]
# ## Finish line 🏁
#
# ---
#
# To get credit for completing the programming component of this lab, **show your TA this notebook** with a graph of your name above.
